# %%
#this is the training part for the CHAT dataset
#the source is main_chat.py, from the original GitHub repository

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
newpath = "/content/drive/My Drive/Colab Notebooks/"

# !pip install tensorflow_addons
# !pip install mne

import sys
sys.path.append("/content/drive/My Drive/Colab Notebooks/")

newpath2 = newpath + "test.py"
# !cp "$newpath2".

newpath3 = newpath + "train.py"
# !cp "$newpath3".

newpath4 = newpath + "metrics.py"
# !cp "$newpath4".

newpath5 = newpath + "data.py"
# !cp "$newpath5".

newpath6 = newpath + "sleep_study"
# !cp "$newpath6".

#import sleep_study
import data


import keras
import sys

#from test import test
import test
#from train import train
import train

# 0- E1 - M2
# 1- E2 - M1

# 2- F3 - M2
# 3- F4 - M1
# 4- C3 - M2
# 5- C4 - M1
# 6- O1 - M2
# 7- O2 - M1

# 8- ECG3 - ECG1

# 9- CANULAFLOW
# 10- AIRFLOW
# 11- CHEST
# 12- ABD

# 13- SAO2
# 14- CAP
######### ADDED IN THIS STEP #########
# 15- RRI
# 16 Ramp

sig_dict_chat = {
    "EOG": [0, 1],
    "EEG": [4, 5],
    "ECG": [15,16],
    "Resp": [9, 10],
    "SPO2": [13],
    "CO2": [14],
}

channel_list_chat = [
    ["ECG", "SPO2"],

]

for ch in channel_list_chat:
    chs = []
    chstr = ""
    for name in ch:
        chstr += name
        chs = chs + sig_dict_chat[name]
    print(chstr, chs)
    config = {
        "data_path": "/content/drive/My Drive/Colab Notebooks/_1.npz",
        "model_path": "/content/drive/My Drive/Colab Notebooks/saved_model.pt",
        "model_name": "hybrid_"+ chstr,
        "regression": False,

        "transformer_layers": 5,  # best 5
        "drop_out_rate": 0.25,  # best 0.25
        "num_patches": 30,  # best 30 TBD
        "transformer_units": 32,  # best 32
        "regularization_weight": 0.001,  # best 0.001
        "num_heads": 4,
        "epochs": 100,  # best 200
        "channels": chs,
    }
    train.train(config, 0)
    # test(config, 0)
# Out:
# Mounted at /content/drive
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (24.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (2.13.3)
# Requirement already satisfied: mne in /usr/local/lib/python3.10/dist-packages (1.6.1)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from mne) (1.25.2)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mne) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from mne) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mne) (4.66.2)
# Requirement already satisfied: pooch>=1.5 in /usr/local/lib/python3.10/dist-packages (from mne) (1.8.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from mne) (4.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from mne) (24.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from mne) (3.1.3)
# Requirement already satisfied: lazy-loader>=0.3 in /usr/local/lib/python3.10/dist-packages (from mne) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.0->mne) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (4.2.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.5->mne) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->mne) (2.1.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.0->mne) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.5->mne) (2024.2.2)
# cp: missing destination file operand after '/content/drive/My Drive/Colab Notebooks/test.py.'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/My Drive/Colab Notebooks/train.py.'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/My Drive/Colab Notebooks/metrics.py.'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/My Drive/Colab Notebooks/data.py.'
# Try 'cp --help' for more information.
# cp: missing destination file operand after '/content/drive/My Drive/Colab Notebooks/sleep_study.'
# Try 'cp --help' for more information.
# ECGSPO2 [15, 16, 13]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1f6200a1284a> in <cell line: 77>()
#      97         "channels": chs,
#      98     }
# ---> 99     train.train(config, 0)
#     100     # test(config, 0)
#     101
#
# /content/drive/My Drive/Colab Notebooks/train.py in train(config, fold)
#      25     ########################################################################################
#      26     for i in range(FOLD):
# ---> 27         x[i], y[i] = shuffle(x[i], y[i])
#      28         x[i] = np.nan_to_num(x[i], nan=1)
#      29         if config["regression"]:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py in shuffle(random_state, n_samples, *arrays)
#     681       array([0, 1])
#     682     """
# --> 683     return resample(
#     684         *arrays, replace=False, n_samples=n_samples, random_state=random_state
#     685     )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/__init__.py in resample(replace, n_samples, random_state, stratify, *arrays)
#     567         )
#     568
# --> 569     check_consistent_length(*arrays)
#     570
#     571     if stratify is None:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     392     """
#     393
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     392     """
#     393
# --> 394     lengths = [_num_samples(X) for X in arrays if X is not None]
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     333     if hasattr(x, "shape") and x.shape is not None:
#     334         if len(x.shape) == 0:
# --> 335             raise TypeError(
#     336                 "Singleton array %r cannot be considered a valid collection." % x
#     337             )
#
# TypeError: Singleton array 0 cannot be considered a valid collection.
